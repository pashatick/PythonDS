# %%
import numpy as np
import pandas as pn
import sklearn
import matplotlib

# %%
data = pn.read_csv('~/anaconda3/Kurs_project_task/train.csv')

# %%
data.describe()
# Out:
#                 Id    DistrictId         Rooms        Square   LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  7887.000000
# mean    8383.40770     50.400800      1.890500     56.315775    37.199645
# std     4859.01902     43.587592      0.839512     21.058732    86.241209
# min        0.00000      0.000000      0.000000      1.136859     0.370619
# 25%     4169.50000     20.000000      1.000000     41.774881    22.769832
# 50%     8394.50000     36.000000      2.000000     52.513310    32.781260
# 75%    12592.50000     75.000000      2.000000     65.900625    45.128803
# max    16798.00000    209.000000     19.000000    641.065193  7480.592129
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  1.000000e+04  10000.000000
# mean        6.273300      8.526700     12.609400  3.990166e+03      0.118858
# ...

# %% [markdown]
# Поменял местами этажность и этаж квартиры, там где этаж превышает этажность

# %%
dt = data.loc[data['Floor'] > data['HouseFloor']]

# %%
dt['Floor'], dt['HouseFloor'] = dt['HouseFloor'],dt['Floor']
# Out:
# /home/pavel/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data.loc[data['Floor'] > data['HouseFloor']] = dt

# %% [markdown]
# далее выровнял соотношение общей площади к жилой площади и площади кухни исходя из того, что
#     для однокомнатной квартиры установлены особые требования по количеству квадратных метров в жилой комнате - 14, тогда как в двух- и более комнатных жилищах планка поднята выше - до 16 для общей комнаты и 9 - для остальных жилых помещений.
#     Размер спальни для всех квартир должен быть не менее восьми квадратных метров.
#     Для кухни в двухкомнатной квартире установлены минимальные значения в 8 квадратных метров и, если речь идет о зонировании помещения, то 6 метров для зоны кухни в помещении столовой.
#     В однокомнатной квартире разрешается устраивать кухни не менее шести метров и кухни ниши (5 метров).
# http://gsps.ru/poleznoe/minimalnaya-ploshchad-pomeshcheniy-kvartiry.php

# %%
dt1 = data.loc[data['LifeSquare']>data['Square']]

# %%
dt1['LifeSquare'] = dt1['Square'] - dt1['KitchenSquare']
# Out:
# /home/pavel/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data.loc[data['Rooms']==1].loc[data['LifeSquare']<12]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 160    3522           6    1.0   66.419841    3.987101            1.0    1.0
# 270   15215          17    1.0   46.692974    5.941401            1.0    1.0
# 363   15751           9    1.0   44.171793    1.251846            1.0   11.0
# 477    8849          45    1.0   63.419553    2.286357            1.0    1.0
# 527    2141          56    1.0   53.733677    4.323046            1.0    1.0
# 674   10631          88    1.0   42.571618    1.941521            1.0    1.0
# 695    1867          30    1.0   54.626206    4.651397            1.0    3.0
# 707    4345          62    1.0   49.275155    1.377284            1.0    1.0
# 734    4319          62    1.0   51.815214    4.203073            1.0    1.0
# 765    7060          27    1.0   38.651043    5.822657            1.0    7.0
# 850    2470           6    1.0   43.312025    1.404493            1.0   11.0
# ...

# %%
data.loc[data['Rooms']==1].describe()
# Out:
#                  Id   DistrictId   Rooms       Square   LifeSquare  \
# count   3705.000000  3705.000000  3705.0  3705.000000  2827.000000
# mean    8406.774629    47.137652     1.0    41.323277    25.159008
# std     4851.019498    40.832580     0.0    11.427651    14.202326
# min        0.000000     0.000000     1.0     1.136859     0.370619
# 25%     4063.000000    20.000000     1.0    36.692587    19.681268
# 50%     8486.000000    30.000000     1.0    40.406590    21.663929
# 75%    12628.000000    66.000000     1.0    43.565368    24.232240
# max    16798.000000   209.000000     1.0   409.425181   410.639749
#
#        KitchenSquare        Floor   HouseFloor     HouseYear    Ecology_1  \
# count    3705.000000  3705.000000  3705.000000  3.705000e+03  3705.000000
# mean        6.525776     7.834278    13.927665  7.398392e+03     0.122414
# std        46.385219     5.363319     6.053992  3.293979e+05     0.122182
# ...

# %%
data.describe()
# Out:
#                 Id    DistrictId         Rooms        Square  LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000     10000.0
# mean    8383.40770     50.400800      1.890500     56.315775        14.0
# std     4859.01902     43.587592      0.839512     21.058732         0.0
# min        0.00000      0.000000      0.000000      1.136859        14.0
# 25%     4169.50000     20.000000      1.000000     41.774881        14.0
# 50%     8394.50000     36.000000      2.000000     52.513310        14.0
# 75%    12592.50000     75.000000      2.000000     65.900625        14.0
# max    16798.00000    209.000000     19.000000    641.065193        14.0
#
#        KitchenSquare        Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.00000  10000.000000  1.000000e+04  10000.000000
# mean        6.273300      7.70040     13.435700  3.990166e+03      0.118858
# std        28.560917      5.30406      6.094012  2.005003e+05      0.119025
# ...

# %%
ls2 = data.loc[data['Rooms']==2].loc[data['LifeSquare'] < 10.5*2]

# %%
ls2['LifeSquare'] = 16*ls2['Rooms']

# %%
data.loc[data['Rooms']==2].loc[data['LifeSquare'] < 10.5*2] = ls2

# %%
ls3 = data.loc[data['Rooms']==3].loc[data['LifeSquare']<10.5*3]

# %%
ls3['LifeSquare'] = 14*ls3['Rooms']

# %%
data.loc[data['Rooms']==3].loc[data['LifeSquare']<10.5*3]=ls3

# %%
ls4 = data.loc[data['Rooms']==4].loc[data['LifeSquare']<10.5*4]

# %%
ls4['LifeSquare'] = 16*ls4['Rooms']

# %%
data.loc[data['Rooms']==4].loc[data['LifeSquare']<10.5*4] = ls4

# %%
ls5 = data.loc[data['Rooms']==5].loc[data['LifeSquare']<10.5*5]

# %%
ls5['LifeSquare'] = 16*ls5['Rooms']

# %%
data.loc[data['Rooms']==5].loc[data['LifeSquare']<10.5*5] = ls5

# %%
data.loc[data['Rooms']==1].loc[data['LifeSquare']<12] = ls1

# %%
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 160    3522           6    1.0   66.419841    3.987101            1.0    1.0
# 270   15215          17    1.0   46.692974    5.941401            1.0    1.0
# 363   15751           9    1.0   44.171793    1.251846            1.0   11.0
# 477    8849          45    1.0   63.419553    2.286357            1.0    1.0
# 527    2141          56    1.0   53.733677    4.323046            1.0    1.0
# 674   10631          88    1.0   42.571618    1.941521            1.0    1.0
# 695    1867          30    1.0   54.626206    4.651397            1.0    3.0
# 707    4345          62    1.0   49.275155    1.377284            1.0    1.0
# 734    4319          62    1.0   51.815214    4.203073            1.0    1.0
# 765    7060          27    1.0   38.651043    5.822657            1.0    7.0
# 850    2470           6    1.0   43.312025    1.404493            1.0   11.0
# ...
